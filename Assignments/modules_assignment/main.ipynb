# %%
from package_folder.math_utils import add,square
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 from package_folder.math_utils import add,square
#
# ImportError: cannot import name 'square' from 'package_folder.math_utils' (c:\Users\DELL\Desktop\python\Assignments\modules_assignment\package_folder\math_utils.py)
